# %%
# Importamos las librerias necesarias
import numpy as np
import pandas as pd
import seaborn as sns
from pandas_datareader import data
import yfinance as yf

# %%
# Descargo el dataset con yahoo! finance para trabajar en el.
S_P_500 = yf.download('SPY', start = '2000-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Lo llamamos para explorarlo y me doy cuenta que la columna Date esta abajo, python lo esta coinciderando como indice .
S_P_500
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-03  148.250000  148.250000  143.875000  145.437500   95.308777
# 2000-01-04  143.531250  144.062500  139.640625  139.750000   91.581650
# 2000-01-05  139.937500  141.531250  137.250000  140.000000   91.745468
# 2000-01-06  139.625000  141.500000  137.750000  137.750000   90.271019
# 2000-01-07  140.312500  145.750000  140.062500  145.750000   95.513573
# ...                ...         ...         ...         ...         ...
# 2023-02-16  408.790009  412.910004  408.140015  408.279999  408.279999
# 2023-02-17  406.059998  407.510010  404.049988  407.260010  407.260010
# 2023-02-21  403.059998  404.160004  398.820007  399.089996  399.089996
# 2023-02-22  399.519989  401.130005  397.019989  398.540009  398.540009
# 2023-02-23  401.559998  402.200012  396.250000  400.660004  400.660004
#
#               Volume
# Date
# 2000-01-03   8164300
# 2000-01-04   8089800
# 2000-01-05  12177900
# ...

# %%
# Resuelvo el problema con la funcion .reset_index().
S_P_500= S_P_500.reset_index()
S_P_500
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2000-01-03  148.250000  148.250000  143.875000  145.437500   95.308777
# 1    2000-01-04  143.531250  144.062500  139.640625  139.750000   91.581650
# 2    2000-01-05  139.937500  141.531250  137.250000  140.000000   91.745468
# 3    2000-01-06  139.625000  141.500000  137.750000  137.750000   90.271019
# 4    2000-01-07  140.312500  145.750000  140.062500  145.750000   95.513573
# ...         ...         ...         ...         ...         ...         ...
# 5818 2023-02-16  408.790009  412.910004  408.140015  408.279999  408.279999
# 5819 2023-02-17  406.059998  407.510010  404.049988  407.260010  407.260010
# 5820 2023-02-21  403.059998  404.160004  398.820007  399.089996  399.089996
# 5821 2023-02-22  399.519989  401.130005  397.019989  398.540009  398.540009
# 5822 2023-02-23  401.559998  402.200012  396.250000  400.660004  400.660004
#
#         Volume
# 0      8164300
# 1      8089800
# ...

# %%
# Paso el dataframe a csv.
DF_S_P500 = S_P_500.to_csv(r'C:\Users\gaspar\Downloads\PI03-Analytics\DF_S_P500.csv', index=False)

# %%
DF_S_P500 = pd.read_csv (r'C:\Users\gaspar\Downloads\PI03-Analytics\DF_S_P500.csv')
DF_S_P500
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2000-01-03  148.250000  148.250000  143.875000  145.437500   95.308777
# 1     2000-01-04  143.531250  144.062500  139.640625  139.750000   91.581650
# 2     2000-01-05  139.937500  141.531250  137.250000  140.000000   91.745468
# 3     2000-01-06  139.625000  141.500000  137.750000  137.750000   90.271019
# 4     2000-01-07  140.312500  145.750000  140.062500  145.750000   95.513573
# ...          ...         ...         ...         ...         ...         ...
# 5818  2023-02-16  408.790009  412.910004  408.140015  408.279999  408.279999
# 5819  2023-02-17  406.059998  407.510010  404.049988  407.260010  407.260010
# 5820  2023-02-21  403.059998  404.160004  398.820007  399.089996  399.089996
# 5821  2023-02-22  399.519989  401.130005  397.019989  398.540009  398.540009
# 5822  2023-02-23  401.559998  402.200012  396.250000  400.660004  400.660004
#
#         Volume
# 0      8164300
# ...

# %%
sns.countplot(x='Volume', data= S_P_500)
# Out:
# <AxesSubplot: xlabel='Volume', ylabel='count'>

# %% [markdown]
# Observando el grafico, nos damos cuenta que tenemos un gran volumen de datos, esto hay que tenerlo en cuenta a la hora de analizar, e ir a los periodos específicos más relevantes para exponer en detalle los altos y bajos de indice a nuestro clinete.

# %% [markdown]
# Verifico si existen valores nulos en el data frame, no hay valores nulos.

# %%
DF_S_P500.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# Descargo el Data set de las compañias para recomendar inversión , desde el año 2000 en adelante para explorarlo y obtener informacion relebante.
Pepsi_Co = yf.download('PEP', start = '2000-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
Pepsi_Co.reset_index()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2000-01-03   35.375000   37.375000   35.000000   36.875000   20.958076
# 1    2000-01-04   36.562500   37.562500   35.750000   35.937500   20.425249
# 2    2000-01-05   35.812500   36.312500   34.875000   35.062500   19.927925
# 3    2000-01-06   34.750000   36.875000   34.500000   36.625000   20.815987
# 4    2000-01-07   36.875000   38.625000   36.687500   37.625000   21.384352
# ...         ...         ...         ...         ...         ...         ...
# 5821 2023-02-22  176.720001  177.429993  175.770004  176.119995  176.119995
# 5822 2023-02-23  176.660004  176.990005  174.990005  176.309998  176.309998
# 5823 2023-02-24  175.460007  176.330002  174.289993  175.960007  175.960007
# 5824 2023-02-27  176.970001  177.250000  175.649994  175.910004  175.910004
# 5825 2023-02-28  174.880005  175.057495  173.199997  173.529999  173.529999
#
#         Volume
# 0      5298400
# 1      4555700
# ...

# %%
DF_AAPL = yf.download('AAPL', start = '2000-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
DF_AAPL.reset_index()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2000-01-03    0.936384    1.004464    0.907924    0.999442    0.850643
# 1    2000-01-04    0.966518    0.987723    0.903460    0.915179    0.778926
# 2    2000-01-05    0.926339    0.987165    0.919643    0.928571    0.790324
# 3    2000-01-06    0.947545    0.955357    0.848214    0.848214    0.721931
# 4    2000-01-07    0.861607    0.901786    0.852679    0.888393    0.756128
# ...         ...         ...         ...         ...         ...         ...
# 5819 2023-02-17  152.350006  153.000000  150.850006  152.550003  152.550003
# 5820 2023-02-21  150.199997  151.300003  148.410004  148.479996  148.479996
# 5821 2023-02-22  148.869995  149.949997  147.160004  148.910004  148.910004
# 5822 2023-02-23  150.089996  150.339996  147.240005  149.399994  149.399994
# 5823 2023-02-24  147.110001  147.190002  145.720001  146.710007  146.710007
#
#          Volume
# 0     535796800
# 1     512377600
# ...

# %%
DF_AMAZON_MX = yf.download('AMZN.MX', start = '2000-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
DF_AMAZON_MX.reset_index()
# Out:
#            Date         Open         High          Low        Close  \
# 0    2008-01-02    51.575001    51.575001    51.575001    51.575001
# 1    2008-01-03    51.575001    51.575001    51.575001    51.575001
# 2    2008-01-04    51.575001    51.575001    51.575001    51.575001
# 3    2008-01-07    51.575001    51.575001    51.575001    51.575001
# 4    2008-01-08    51.575001    51.575001    51.575001    51.575001
# ...         ...          ...          ...          ...          ...
# 3801 2023-02-20  1800.000000  1809.000000  1785.319946  1785.500000
# 3802 2023-02-21  1784.689941  1784.689941  1735.000000  1747.489990
# 3803 2023-02-22  1748.000000  1799.979980  1747.040039  1755.609985
# 3804 2023-02-23  1760.630005  1769.589966  1725.640015  1758.770020
# 3805 2023-02-24  1731.000000  1754.880005  1700.469971  1709.239990
#
#         Adj Close  Volume
# 0       51.575001    2000
# 1       51.575001       0
# 2       51.575001       0
# 3       51.575001       0
# ...

# %%
DF_MICROSOFT = yf.download('MSF.DU', start = '2000-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
DF_MICROSOFT.reset_index()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2008-01-07   23.299999   23.299999   23.299999   23.299999   17.061714
# 1    2008-01-11   23.030001   23.030001   23.030001   23.030001   16.864006
# 2    2008-01-21   22.219999   22.219999   22.000000   22.000000   16.109779
# 3    2008-01-22   20.350000   20.350000   20.350000   20.350000   14.901548
# 4    2008-01-24   21.670000   22.030001   21.670000   22.030001   16.131748
# ...         ...         ...         ...         ...         ...         ...
# 3653 2023-02-20  241.500000  242.399994  240.850006  240.850006  240.850006
# 3654 2023-02-21  240.800003  241.399994  235.550003  236.350006  236.350006
# 3655 2023-02-22  237.149994  238.100006  236.199997  236.199997  236.199997
# 3656 2023-02-23  237.550003  241.600006  237.000000  239.000000  239.000000
# 3657 2023-02-24  239.600006  239.600006  235.500000  235.750000  235.750000
#
#       Volume
# 0         81
# 1         90
# ...

# %%
# Obtengo los dataset con el ROE de cada empresa para tener datos mas certeros para recomendar inversion y satisfacer las inquetudes del cliente.
